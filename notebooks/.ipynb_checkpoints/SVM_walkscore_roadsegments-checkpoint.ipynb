# %% [markdown]
# # SVM for Walkscore

# %%
import pandas as pd 
import numpy as np
import pylab as pl

from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn import svm
from sklearn.grid_search import GridSearchCV
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split

import scipy.stats as stats
import math
import warnings
import os

# %pylab inline
warnings.filterwarnings("ignore")

pl.style.use('fivethirtyeight')
pl.rcParams['figure.figsize'] = (16,16)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('../data/df_walkscore.pkl')

# %% [markdown]
# ## Data Exploration

# %%
data['walkscore'].describe()
# Out:
# count    30100.000000
# mean        91.719734
# std          7.617988
# min         41.000000
# 25%         87.000000
# 50%         95.000000
# 75%         97.000000
# max        100.000000
# Name: walkscore, dtype: float64

# %%
sorted_walkscore = sorted(data['walkscore'])
fit = stats.norm.pdf(sorted_walkscore, np.mean(sorted_walkscore), np.std(sorted_walkscore))

# %%
pl.plot(sorted_walkscore, fit,'-o');
pl.hist(data['walkscore'], normed=True, bins = 50);
pl.xlabel('Walkscore');
pl.ylabel('Proportion of Observations');
pl.title('Distribution of Walkscore Values', size = 30);

# %% [markdown]
# ## Classifing walkscore by quintiles

# %%
data['walkscore_class'] = np.zeros(len(data['walkscore']))

# %%
data['walkscore_class'].ix[data['walkscore'] < 87.000000] = 0
data['walkscore_class'].ix[(data['walkscore'] >= 87.000000) & (data['walkscore'] < 95.000000)] = 1
data['walkscore_class'].ix[(data['walkscore'] >= 95.000000) & (data['walkscore'] < 97.000000)] = 2
data['walkscore_class'].ix[data['walkscore'] > 97.000000] = 3

# %%
x_values = data.iloc[:,0:16].values
y_values = data['walkscore_class'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x_values, y_values, test_size=0.33, random_state=42)

# %% [markdown]
# ## Kernels

# %%
#Linear Kernel
bool_clf = OneVsRestClassifier(svm.SVC(kernel='linear', C=1.0, class_weight='balanced'))
bool_clf.fit(x_train, y_train)
linear_y_pred = bool_clf.predict(x_test)
right=1.0*(linear_y_pred==np.asarray(y_test)).sum()/len(y_test)

print "we successfully(OS) predict the {} percent of data using a linear kernel".format((right)*100)
os.system('say "First Linear Done"');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-ac3797c64387> in <module>()
#       1 #Linear Kernel
#       2 bool_clf = OneVsRestClassifier(svm.SVC(kernel='linear', C=1.0, class_weight='balanced'))
# ----> 3 bool_clf.fit(x_train, y_train)
#       4 linear_y_pred = bool_clf.predict(x_test)
#       5 right=1.0*(linear_y_pred==np.asarray(y_test)).sum()/len(y_test)
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/multiclass.pyc in fit(self, X, y)
#     285                 "not %s" % self.label_binarizer_.classes_[i],
#     286                 self.label_binarizer_.classes_[i]])
# --> 287             for i, column in enumerate(columns))
#     288
#     289         return self
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     798             # was dispatched. In particular this covers the edge
#     799             # case of Parallel used with an exhausted iterator.
# --> 800             while self.dispatch_one_batch(iterator):
#     801                 self._iterating = True
#     802             else:
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     656                 return False
#     657             else:
# --> 658                 self._dispatch(tasks)
#     659                 return True
#     660
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     564
#     565         if self._pool is None:
# --> 566             job = ImmediateComputeBatch(batch)
#     567             self._jobs.append(job)
#     568             self.n_dispatched_batches += 1
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, batch)
#     178         # Don't delay the application, to avoid keeping the input
#     179         # arguments in memory
# --> 180         self.results = batch()
#     181
#     182     def get(self):
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/multiclass.pyc in _fit_binary(estimator, X, y, classes)
#      72     else:
#      73         estimator = clone(estimator)
# ---> 74         estimator.fit(X, y)
#      75     return estimator
#      76
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     148         self._sparse = sparse and not callable(self.kernel)
#     149
# --> 150         X = check_array(X, accept_sparse='csr', dtype=np.float64, order='C')
#     151         y = self._validate_targets(y)
#     152
#
# /home/cusp/vv744/.conda/envs/plume_conda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     371                                       force_all_finite)
#     372     else:
# --> 373         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     374
#     375         if ensure_2d:
#
# ValueError: invalid literal for float(): 42.333324|-71.073692
